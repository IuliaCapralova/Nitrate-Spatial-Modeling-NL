# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file('/Users/Administrator/Documents/University/Year 3/2b/Thesis/Bachelor-Thesis/data/clean/soil_composition/layernumber_1_processed.gpkg')

# 2. Check the contents
print(gdf.head())
print(gdf.crs)

# 3. Plot it
gdf.plot()
plt.title("GeoPackage Data")
plt.show()
# Out:
#                      maparea_id       soilslope soilunit_code  \
# 0  V2024-1..soilarea.0000007878  Niet opgenomen         bEZ23
# 1  V2024-1..soilarea.0000007880  Niet opgenomen         bEZ23
# 2  V2024-1..soilarea.0000007881  Niet opgenomen         bEZ23
# 3  V2024-1..soilarea.0000007886  Niet opgenomen         bEZ23
# 4  V2024-1..soilarea.0000007892  Niet opgenomen         bEZ23
#
#   mainsoilclassification  normalsoilprofile_id  layernumber  \
# 0      Dikke eerdgronden               9028040            1
# 1      Dikke eerdgronden               9018040            1
# 2      Dikke eerdgronden               9028040            1
# 3      Dikke eerdgronden               9028040            1
# 4      Dikke eerdgronden               9028040            1
#
#   faohorizonnotation  lowervalue  uppervalue  organicmattercontent  ...  \
# 0                Aap         0.0        0.25                   3.4  ...
# 1                Aap         0.0        0.25                   3.1  ...
# 2                Aap         0.0        0.25                   3.4  ...
# 3                Aap         0.0        0.25                   3.4  ...
# 4                Aap         0.0        0.25                   3.4  ...
#
#    maximumloamcontent  lutitecontent  minimumlutitecontent  \
# 0                  35              7                     4
# 1                  35              7                     4
# 2                  35              7                     4
# 3                  35              7                     4
# 4                  35              7                     4
#
#    maximumlutitecontent  sandmedian  minimumsandmedian maximumsandmedian  \
# 0                    10         150                130               180
# 1                    10         150                130               180
# 2                    10         150                130               180
# 3                    10         150                130               180
# 4                    10         150                130               180
#
#    siltcontent  density                                           geometry
# 0           16    1.420  MULTIPOLYGON (((164717.594 454012.75, 164756.9...
# 1           16    1.432  MULTIPOLYGON (((160216.327 456809.549, 160205....
# 2           16    1.420  MULTIPOLYGON (((161520.938 457135.313, 161480....
# 3           16    1.420  MULTIPOLYGON (((161584.516 460209.687, 161567....
# 4           16    1.420  MULTIPOLYGON (((161526.375 462600.313, 161516....
#
# [5 rows x 31 columns]
# EPSG:28992

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="knmi_locator")

stations = ["De Bilt", "Schiphol", "Ell", "Rotterdam Geulhaven"]
coords = {}

for name in stations:
    location = geolocator.geocode(f"{name}, Netherlands")
    if location:
        coords[name] = (location.longitude, location.latitude)

print(coords)
# Out:
# /Users/Administrator/Documents/University/Year 3/2b/Thesis/Bachelor-Thesis/spatial_env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# {'De Bilt': (5.1737773, 52.1445592), 'Schiphol': (4.7621975, 52.3080392), 'Ell': (5.7949461, 51.2197788), 'Rotterdam Geulhaven': (4.3124116, 51.8895294)}

# %%
depth_temp_path = '/Users/Administrator/Documents/University/Year 3/2b/Thesis/Bachelor-Thesis/src/depth_temp.csv'
merged_data_path = '/Users/Administrator/Documents/University/Year 3/2b/Thesis/Bachelor-Thesis/data/aligned/merged_dataset_1.csv'

# %%
depth_temp = pd.read_csv(depth_temp_path)
merged_data = pd.read_csv(merged_data_path)

# %%
depth_temp["groundwater depth"].isna().sum()
# Out:
# 51

# %%
merged_data["groundwater depth"].isna().sum()
# Out:
# 70

# %%
import os
import multiprocessing

print(f"Total logical CPUs: {multiprocessing.cpu_count()}")
print(f"Process ID: {os.getpid()}")
# Out:
# Total logical CPUs: 11
# Process ID: 1476
