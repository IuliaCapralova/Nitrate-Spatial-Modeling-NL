# %%
import fiona
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
path = "/Users/Administrator/Downloads/brpgewaspercelen_definitief_2018/BRP_Gewaspercelen_2018.gdb"
gdf = gpd.read_file(path)
print(gdf.head())
# Out:
#   CAT_GEWASCATEGORIE GWS_GEWASCODE  GEOMETRIE_Length  GEOMETRIE_Area  \
# 0           Grasland           265       1214.908493    48048.099400
# 1           Grasland           265        701.257524    21093.170162
# 2           Grasland           265        719.495022    19126.484549
# 3           Grasland           265        356.893149     7832.003569
# 4           Grasland           265        234.536070     2595.918606
#
#             GWS_GEWAS                                           geometry
# 0  Grasland, blijvend  MULTIPOLYGON (((203617.226 560919.499, 203624....
# 1  Grasland, blijvend  MULTIPOLYGON (((201240.151 560009.466, 201229....
# 2  Grasland, blijvend  MULTIPOLYGON (((201627.652 557262.366, 201588....
# 3  Grasland, blijvend  MULTIPOLYGON (((160512.183 393273.503, 160482....
# 4  Grasland, blijvend  MULTIPOLYGON (((160571.409 393422.947, 160586....

# %%
fiona.listlayers(path)
# Out:
# ['BRP_gewaspercelen_2018']

# %%
gdf.plot(figsize=(10, 10), column=None, edgecolor="black")
plt.title("BRP Gewaspercelen 2018")
plt.axis("off")
plt.tight_layout()
plt.show()
